# %% [markdown]
# <h1 style="color: blue; font-family: Algerian; font-weight: bold;">ATTRITION ANALYSIS 💼📉</h1>

# %% [markdown]
# * In this dataset, we are going to understand and tackle employee turnover. Reveal the determinants contributing to employee attrition.We will investigate inquiries like 'provide a breakdown of distance from home based on gender, hourly rate, department, daily rate, job role and attrition' or 'compare average monthly income by education, gender, hourly rate, department, daily rate, job role and attrition'.
# * We will delve into aspects such as job satisfaction, career advancement, and various other factors, aiming to understand the elements that influence individuals to either remain in or leave their roles.
# * Advanced data technologies such as Machine Learning can be instrumental in predicting whether an individual with a specific status will continue to be a part of the company or not.

# %% [markdown]
# <h2 style="color: orange; font-family: Helvetica; font-weight: bold;">EXPLORATORY DATA ANALYSIS</h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
df = pd.read_csv("D:\\Data Science Projects\\Attrition Analysis\\ATTRITION.csv")

# %%
df.head(10)
# Out:
#     EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0   RM297   18    18-25       Yes      Travel_Rarely        230
# 1   RM302   18    18-25        No      Travel_Rarely        812
# 2   RM458   18    18-25       Yes  Travel_Frequently       1306
# 3   RM728   18    18-25        No         Non-Travel        287
# 4   RM829   18    18-25       Yes         Non-Travel        247
# 5   RM973   18    18-25        No         Non-Travel       1124
# 6  RM1154   18    18-25       Yes  Travel_Frequently        544
# 7  RM1312   18    18-25        No         Non-Travel       1431
# 8   RM128   19    18-25       Yes      Travel_Rarely        528
# 9   RM150   19    18-25        No      Travel_Rarely       1181
#
#                Department  DistanceFromHome  Education EducationField  ...  \
# 0  Research & Development                 3          3  Life Sciences  ...
# 1                   Sales                10          3        Medical  ...
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1480.000000  1480.000000       1480.000000  1480.000000         1480.0
# mean     36.917568   801.384459          9.220270     2.910811            1.0
# std       9.128559   403.126988          8.131201     1.023796            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   800.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1480.000000              1480.000000  1480.000000     1480.000000
# mean      1031.860811                 2.724324    65.845270        2.729730
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1480 entries, 0 to 1479
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmpID                     1480 non-null   object
#  1   Age                       1480 non-null   int64
#  2   AgeGroup                  1480 non-null   object
#  3   Attrition                 1480 non-null   object
#  4   BusinessTravel            1480 non-null   object
#  5   DailyRate                 1480 non-null   int64
#  6   Department                1480 non-null   object
#  7   DistanceFromHome          1480 non-null   int64
#  8   Education                 1480 non-null   int64
#  9   EducationField            1480 non-null   object
#  10  EmployeeCount             1480 non-null   int64
#  11  EmployeeNumber            1480 non-null   int64
#  12  EnvironmentSatisfaction   1480 non-null   int64
#  13  Gender                    1480 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# AgeGroup                    0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# SalarySlab                  0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# dtype: int64

# %% [markdown]
# * Given that the count of non-null values is consistent across all attributes, it can be concluded that the dataset does not contain any missing values.

# %% [markdown]
# * While building the model or conducting the analysis, some columns in the dataframe may not significantly impact the main result, even though they are included as factors for attrition.

# %%
drop_col = ["EmpID", "EmployeeCount", "Education", "EmployeeNumber", "Over18"]
df = df.drop(columns=drop_col, axis=1)

# %%
df.head(10)
# Out:
#    Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0   18    18-25       Yes      Travel_Rarely        230
# 1   18    18-25        No      Travel_Rarely        812
# 2   18    18-25       Yes  Travel_Frequently       1306
# 3   18    18-25        No         Non-Travel        287
# 4   18    18-25       Yes         Non-Travel        247
# 5   18    18-25        No         Non-Travel       1124
# 6   18    18-25       Yes  Travel_Frequently        544
# 7   18    18-25        No         Non-Travel       1431
# 8   19    18-25       Yes      Travel_Rarely        528
# 9   19    18-25        No      Travel_Rarely       1181
#
#                Department  DistanceFromHome EducationField  \
# 0  Research & Development                 3  Life Sciences
# 1                   Sales                10        Medical
# 2                   Sales                 5      Marketing
# 3  Research & Development                 5  Life Sciences
# ...

# %%
column_mode = df['Age'].mode().values[0]
print( column_mode)
# Out:
# 34

# %%
column_mode = df['AgeGroup'].mode().values[0]
print( column_mode)
# Out:
# 26-35

# %%
sns.set_palette("rocket")

plt.figure(figsize=(8, 5))
sns.countplot(data = df, x = "AgeGroup", hue = "AgeGroup", alpha = 0.5)
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title("Count of Age Groups in the the Company")
plt.xticks(rotation = 45, fontsize = 8)
plt.show()

# %% [markdown]
# Observing the data reveals that the largest proportion of individuals falls within the age range of 26-35 years within the company, with a notable concentration around the age of 34.

# %%
column_mode = df['Department'].mode().values[0]
print( column_mode)
# Out:
# Research & Development

# %%
column_mean = df['EnvironmentSatisfaction'].mean()
print("Mean:", column_mean)
# Out:
# Mean: 2.7243243243243245

# %%
column_value_counts = df['Gender'].value_counts()
print("Value counts:\n", column_value_counts)
# Out:
# Value counts:
#  Gender
# Male      889
# Female    591
# Name: count, dtype: int64

# %%
column_mean = df['JobInvolvement'].mean()
print("Mean:", column_mean)
# Out:
# Mean: 2.72972972972973

# %%
column_mode = df['JobRole'].mode().values[0]
print( column_mode)
# Out:
# Sales Executive

# %%
column_mean = df['JobSatisfaction'].mean()
print("Mean:", column_mean)
# Out:
# Mean: 2.725

# %%
column_value_counts = df['MaritalStatus'].value_counts()
print("Value counts:\n", column_value_counts)
column_mode = df['MaritalStatus'].mode().values[0]
print("Mode: ", column_mode)
# Out:
# Value counts:
#  MaritalStatus
# Married     679
# Single      473
# Divorced    328
# Name: count, dtype: int64
# Mode:  Married

# %%
column_mean = df['MonthlyIncome'].mean()
print("Mean:", column_mean)
# Out:
# Mean: 6504.985810810811

# %%
column_value_counts = df['SalarySlab'].value_counts()
print("Value counts:\n", column_value_counts)
# Out:
# Value counts:
#  SalarySlab
# Upto 5k    753
# 5k-10k     444
# 10k-15k    150
# 15k+       133
# Name: count, dtype: int64

# %%
column_mean = df['PercentSalaryHike'].mean()
print("Mean:", column_mean)
# Out:
# Mean: 15.210135135135134

# %%
column_value_counts = df['PerformanceRating'].value_counts()
print("Value counts:\n", column_value_counts)
column_value_counts = df['RelationshipSatisfaction'].value_counts()
print("Value counts:\n", column_value_counts)
# Out:
# Value counts:
#  PerformanceRating
# 3    1253
# 4     227
# Name: count, dtype: int64
# Value counts:
#  RelationshipSatisfaction
# 3    460
# 4    434
# 2    307
# 1    279
# Name: count, dtype: int64

# %%
ages = df['Age']
plt.hist(ages, bins=20, color='red', edgecolor='black', alpha = 0.5)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages')
plt.show()

# %%
sns.displot(df,x="Age",hue="AgeGroup")
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age and AgeGroup Together')
plt.show()

# %%
sns.countplot(data = df, x = "Gender", hue= "Gender", alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# ([0, 1], [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
sns.countplot(data = df, x = "BusinessTravel", hue= "BusinessTravel", alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Travel_Rarely'),
#   Text(1, 0, 'Travel_Frequently'),
#   Text(2, 0, 'Non-Travel'),
#   Text(3, 0, 'TravelRarely')])

# %%
sns.countplot(data = df, x = "Department", hue= "Department", alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Research & Development'),
#   Text(1, 0, 'Sales'),
#   Text(2, 0, 'Human Resources')])

# %%
sns.countplot(data = df, x = "EducationField", hue= "EducationField", alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Life Sciences'),
#   Text(1, 0, 'Medical'),
#   Text(2, 0, 'Marketing'),
#   Text(3, 0, 'Technical Degree'),
#   Text(4, 0, 'Other'),
#   Text(5, 0, 'Human Resources')])

# %%
sns.countplot(data = df, x = "JobRole", hue= "JobRole", alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Laboratory Technician'),
#   Text(1, 0, 'Sales Representative'),
#   Text(2, 0, 'Research Scientist'),
#   Text(3, 0, 'Human Resources'),
#   Text(4, 0, 'Manufacturing Director'),
#   Text(5, 0, 'Sales Executive'),
#   Text(6, 0, 'Healthcare Representative'),
#   Text(7, 0, 'Research Director'),
#   Text(8, 0, 'Manager')])

# %%
sns.countplot(data = df, x = "MaritalStatus", hue= "MaritalStatus", alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Single'), Text(1, 0, 'Divorced'), Text(2, 0, 'Married')])

# %%
sns.countplot(data = df, x = "OverTime", hue= "OverTime", alpha = 0.5)
# Out:
# <Axes: xlabel='OverTime', ylabel='count'>

# %%
sns.countplot(data = df, x = "SalarySlab", hue= "SalarySlab", alpha = 0.5)
plt.xticks(rotation = 45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Upto 5k'),
#   Text(1, 0, '5k-10k'),
#   Text(2, 0, '10k-15k'),
#   Text(3, 0, '15k+')])

# %%
sns.countplot(data = df, x = "EnvironmentSatisfaction", hue= "EnvironmentSatisfaction", alpha = 0.5)
# Out:
# <Axes: xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
sns.countplot(data = df, x = "JobInvolvement", hue= "JobInvolvement", alpha = 0.5)
# Out:
# <Axes: xlabel='JobInvolvement', ylabel='count'>

# %%
sns.countplot(data = df, x = "JobLevel", hue= "JobLevel", alpha = 0.5)
# Out:
# <Axes: xlabel='JobLevel', ylabel='count'>

# %%
sns.countplot(data = df, x = "JobSatisfaction", hue= "JobSatisfaction", alpha = 0.5)
# Out:
# <Axes: xlabel='JobSatisfaction', ylabel='count'>

# %%
sns.countplot(data = df, x = "PerformanceRating", hue= "PerformanceRating", alpha = 0.5)
# Out:
# <Axes: xlabel='PerformanceRating', ylabel='count'>

# %%
sns.countplot(data = df, x = "RelationshipSatisfaction", hue= "RelationshipSatisfaction", alpha = 0.5)
# Out:
# <Axes: xlabel='RelationshipSatisfaction', ylabel='count'>

# %%
sns.countplot(data = df, x = "PercentSalaryHike", hue= "PercentSalaryHike", alpha = 0.5)
# Out:
# <Axes: xlabel='PercentSalaryHike', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['AgeGroup'], df['MonthlyIncome'])

plt.title('Monthly Income by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Monthly Income')
plt.show()

# %%
sns.countplot(data = df, x = "Attrition", hue= "Attrition", alpha = 0.5)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %%
sns.set_palette("Set2")

sns.displot(df,x="Age",hue="Attrition")
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="AgeGroup",hue="Attrition")
plt.xlabel('AgeGroup')
plt.ylabel('Count')
plt.title('AgeGroup Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="BusinessTravel",hue="Attrition")
plt.xlabel('BusinessTravel')
plt.ylabel('Count')
plt.title('BusinessTravel Attrition')
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="DistanceFromHome",hue="Attrition")
plt.xlabel('DistanceFromHome')
plt.ylabel('Count')
plt.title('DistanceFromHome Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="EducationField",hue="Attrition")
plt.xlabel('EducationField')
plt.ylabel('Count')
plt.title('EducationField Attrition')
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="EnvironmentSatisfaction",hue="Attrition")
plt.xlabel('EnvironmentSatisfaction')
plt.ylabel('Count')
plt.title('EnvironmentSatisfaction Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="Gender",hue="Attrition")
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="JobInvolvement",hue="Attrition")
plt.xlabel('JobInvolvement')
plt.ylabel('Count')
plt.title('JobInvolvement Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="JobLevel",hue="Attrition")
plt.xlabel('JobLevel')
plt.ylabel('Count')
plt.title('JobLevel Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="JobRole",hue="Attrition")
plt.xlabel('JobRole')
plt.ylabel('Count')
plt.title('JobRole Attrition')
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="JobSatisfaction",hue="Attrition")
plt.xlabel('JobSatisfaction')
plt.ylabel('Count')
plt.title('JobSatisfaction Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="MaritalStatus",hue="Attrition")
plt.xlabel('MaritalStatus')
plt.ylabel('Count')
plt.title('MaritalStatus Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="SalarySlab",hue="Attrition")
plt.xlabel('SalarySlab')
plt.ylabel('Count')
plt.title('SalarySlab Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="OverTime",hue="Attrition")
plt.xlabel('OverTime')
plt.ylabel('Count')
plt.title('OverTime Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="PercentSalaryHike",hue="Attrition")
plt.xlabel('PercentSalaryHike')
plt.ylabel('Count')
plt.title('PercentSalaryHike Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="MonthlyIncome",hue="Attrition")
plt.xlabel('MonthlyIncome')
plt.ylabel('Count')
plt.title('MonthlyIncome Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="PerformanceRating",hue="Attrition")
plt.xlabel('PerformanceRating')
plt.ylabel('Count')
plt.title('PerformanceRating Attrition')
plt.show()

# %%
sns.set_palette("Set2")

sns.displot(df,x="RelationshipSatisfaction",hue="Attrition")
plt.xlabel('RelationshipSatisfaction')
plt.ylabel('Count')
plt.title('RelationshipSatisfaction Attrition')
plt.show()
